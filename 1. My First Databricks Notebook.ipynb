# %% [markdown]
# # Introduction to Databricks Notebook
#
# My first notebook

# %%
print("hello world")

# %%
# %sql
SELECT 'Hello by sql command' as greeting;

# %% [markdown]
# Magic commands
# - %fs: Run File System commands

# %%
path = dbutils.fs.ls("dbfs:/databricks-datasets/COVID/coronavirusdataset/Case.csv")
df = spark.read.csv(path[0].path, header=True)


df.filter(df["confirmed"]>1000).show()

# %%
# %fs
ls /

# %% [markdown]
# Magic commands
# - %sh Shell commands

# %%
# %sh ps

# %% [markdown]
# Magic commands
# - %pip Install python libreries

# %%
# %pip install faker

# %% [markdown]
# Magic commands
# - %run Run/Import from another Notebook to current Notebook

# %%
# %run "/Workspace/Users/engshka123@gmail.com/test-demo/notebook-1-databricks-platform/2. Variables and Functions"

# %%
print_env_info()
