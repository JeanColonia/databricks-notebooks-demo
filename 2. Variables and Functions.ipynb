# %%
env = "dev"

# %%
import os
import platform

def print_env_info():
    print(f"Python version: {platform.python_version()}")

    runtime_version = os.environ.get("DATABRICKS_RUNTIME_VERSION", "Unknown")
    print(f"Databricks version: {runtime_version}")
